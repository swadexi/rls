# %% [markdown]
# \begin{aligned}
# D =
#
#     \left(\begin{array}{cccccc} -1.051\,{\cos\left(q_{1}\right)}^2+0.524\,\cos\left(q_{1}\right)\,\cos\left(q_{2}\right)+0.1679\,\cos\left(q_{1}\right)\,\cos\left(q_{3}\right)+0.5997\,\cos\left(q_{1}\right)+3.919\,{\cos\left(q_{2}\right)}^2+2.373\,\cos\left(q_{2}\right)\,\cos\left(q_{3}\right)-1.348\,\cos\left(q_{2}\right)-0.1339\,{\cos\left(q_{3}\right)}^2-2.233\,\cos\left(q_{3}\right)-0.524\,\sin\left(q_{1}\right)\,\sin\left(q_{2}\right)-0.1679\,\sin\left(q_{1}\right)\,\sin\left(q_{3}\right)-2.373\,\sin\left(q_{2}\right)\,\sin\left(q_{3}\right)-1.367 & 2.156\,{\cos\left(q_{1}\right)}^2-0.5357\,\cos\left(q_{1}\right)\,\cos\left(q_{2}\right)-1.662\,\cos\left(q_{1}\right)\,\cos\left(q_{3}\right)-1.95\,\cos\left(q_{1}\right)+3.227\,{\cos\left(q_{2}\right)}^2+0.9776\,\cos\left(q_{2}\right)\,\cos\left(q_{3}\right)+3.108\,\cos\left(q_{2}\right)+5.52\,{\cos\left(q_{3}\right)}^2-4.468\,\cos\left(q_{3}\right)+0.5357\,\sin\left(q_{1}\right)\,\sin\left(q_{2}\right)+1.662\,\sin\left(q_{1}\right)\,\sin\left(q_{3}\right)-0.9776\,\sin\left(q_{2}\right)\,\sin\left(q_{3}\right)-5.451 & 1.424\,{\cos\left(q_{1}\right)}^2+0.9123\,\cos\left(q_{1}\right)\,\cos\left(q_{2}\right)+0.3416\,\cos\left(q_{1}\right)\,\cos\left(q_{3}\right)-3.269\,\cos\left(q_{1}\right)-1.466\,{\cos\left(q_{2}\right)}^2+0.2859\,\cos\left(q_{2}\right)\,\cos\left(q_{3}\right)+2.431\,\cos\left(q_{2}\right)+0.2332\,{\cos\left(q_{3}\right)}^2-0.8964\,\cos\left(q_{3}\right)-0.9123\,\sin\left(q_{1}\right)\,\sin\left(q_{2}\right)-0.3416\,\sin\left(q_{1}\right)\,\sin\left(q_{3}\right)-0.2859\,\sin\left(q_{2}\right)\,\sin\left(q_{3}\right)-0.09551 & 0 & 0 & 0\\ 0.002538\,{\cos\left(q_{1}\right)}^2-0.5939\,\cos\left(q_{1}\right)\,\cos\left(q_{2}\right)-0.3939\,\cos\left(q_{1}\right)\,\cos\left(q_{3}\right)+0.7041\,\cos\left(q_{1}\right)+0.2069\,{\cos\left(q_{2}\right)}^2-0.03038\,\cos\left(q_{2}\right)\,\cos\left(q_{3}\right)-0.3508\,\cos\left(q_{2}\right)+0.02129\,{\cos\left(q_{3}\right)}^2+0.5367\,\cos\left(q_{3}\right)+0.5939\,\sin\left(q_{1}\right)\,\sin\left(q_{2}\right)+0.3939\,\sin\left(q_{1}\right)\,\sin\left(q_{3}\right)+0.03038\,\sin\left(q_{2}\right)\,\sin\left(q_{3}\right)-0.1154 & -2.295\,{\cos\left(q_{1}\right)}^2+1.71\,\cos\left(q_{1}\right)\,\cos\left(q_{2}\right)+1.192\,\cos\left(q_{1}\right)\,\cos\left(q_{3}\right)+1.522\,\cos\left(q_{1}\right)-4.249\,{\cos\left(q_{2}\right)}^2-1.035\,\cos\left(q_{2}\right)\,\cos\left(q_{3}\right)+3.435\,\cos\left(q_{2}\right)+0.9763\,{\cos\left(q_{3}\right)}^2-1.413\,\cos\left(q_{3}\right)-1.71\,\sin\left(q_{1}\right)\,\sin\left(q_{2}\right)-1.192\,\sin\left(q_{1}\right)\,\sin\left(q_{3}\right)+1.035\,\sin\left(q_{2}\right)\,\sin\left(q_{3}\right)+2.784 & 1.035\,{\cos\left(q_{1}\right)}^2+0.3659\,\cos\left(q_{1}\right)\,\cos\left(q_{2}\right)+0.2364\,\cos\left(q_{1}\right)\,\cos\left(q_{3}\right)-2.031\,\cos\left(q_{1}\right)+0.5381\,{\cos\left(q_{2}\right)}^2-0.2769\,\cos\left(q_{2}\right)\,\cos\left(q_{3}\right)+0.1871\,\cos\left(q_{2}\right)-0.6219\,{\cos\left(q_{3}\right)}^2+1.075\,\cos\left(q_{3}\right)-0.3659\,\sin\left(q_{1}\right)\,\sin\left(q_{2}\right)-0.2364\,\sin\left(q_{1}\right)\,\sin\left(q_{3}\right)+0.2769\,\sin\left(q_{2}\right)\,\sin\left(q_{3}\right)-0.4754 & 0 & 0 & 0\\ -0.5777\,{\cos\left(q_{1}\right)}^2+0.9596\,\cos\left(q_{1}\right)\,\cos\left(q_{2}\right)+0.087\,\cos\left(q_{1}\right)\,\cos\left(q_{3}\right)+0.1555\,\cos\left(q_{1}\right)+0.9352\,{\cos\left(q_{2}\right)}^2-0.1441\,\cos\left(q_{2}\right)\,\cos\left(q_{3}\right)-2.176\,\cos\left(q_{2}\right)-0.6456\,{\cos\left(q_{3}\right)}^2+1.426\,\cos\left(q_{3}\right)-0.9596\,\sin\left(q_{1}\right)\,\sin\left(q_{2}\right)-0.087\,\sin\left(q_{1}\right)\,\sin\left(q_{3}\right)+0.1441\,\sin\left(q_{2}\right)\,\sin\left(q_{3}\right)+0.1441 & -1.647\,{\cos\left(q_{1}\right)}^2+1.144\,\cos\left(q_{1}\right)\,\cos\left(q_{2}\right)+0.8142\,\cos\left(q_{1}\right)\,\cos\left(q_{3}\right)-0.6635\,\cos\left(q_{1}\right)-6.219\,{\cos\left(q_{2}\right)}^2-1.813\,\cos\left(q_{2}\right)\,\cos\left(q_{3}\right)+4.775\,\cos\left(q_{2}\right)+0.1168\,{\cos\left(q_{3}\right)}^2-0.9439\,\cos\left(q_{3}\right)-1.144\,\sin\left(q_{1}\right)\,\sin\left(q_{2}\right)-0.8142\,\sin\left(q_{1}\right)\,\sin\left(q_{3}\right)+1.813\,\sin\left(q_{2}\right)\,\sin\left(q_{3}\right)+3.875 & 0.6052\,{\cos\left(q_{1}\right)}^2-0.3917\,\cos\left(q_{1}\right)\,\cos\left(q_{2}\right)-0.1363\,\cos\left(q_{1}\right)\,\cos\left(q_{3}\right)-0.0423\,\cos\left(q_{1}\right)-2.699\,{\cos\left(q_{2}\right)}^2+0.5303\,\cos\left(q_{2}\right)\,\cos\left(q_{3}\right)+3.202\,\cos\left(q_{2}\right)+0.9784\,{\cos\left(q_{3}\right)}^2-1.212\,\cos\left(q_{3}\right)+0.3917\,\sin\left(q_{1}\right)\,\sin\left(q_{2}\right)+0.1363\,\sin\left(q_{1}\right)\,\sin\left(q_{3}\right)-0.5303\,\sin\left(q_{2}\right)\,\sin\left(q_{3}\right)+0.5577 & 0 & 0 & 0 \end{array}\right)
#
# \end{aligned}

# %% [markdown]
# \begin{aligned}
#
# H =
#
#     \left(\begin{array}{c} 1.042\,{\mathrm{q1d}}^2\,\sin\left(q_{2}\right)-0.9449\,{\mathrm{q1d}}^2\,\sin\left(q_{1}\right)+0.2541\,{\mathrm{q2d}}^2\,\sin\left(q_{1}\right)+0.2551\,{\mathrm{q1d}}^2\,\sin\left(q_{3}\right)-3.401\,{\mathrm{q2d}}^2\,\sin\left(q_{2}\right)-0.8014\,{\mathrm{q3d}}^2\,\sin\left(q_{1}\right)-0.2223\,{\mathrm{q2d}}^2\,\sin\left(q_{3}\right)-0.6962\,{\mathrm{q3d}}^2\,\sin\left(q_{2}\right)-0.3756\,{\mathrm{q3d}}^2\,\sin\left(q_{3}\right)-0.05162\,{\mathrm{q1d}}^2\,\mathrm{sign}\left(\mathrm{q1d}\right)-0.7831\,{\mathrm{q2d}}^2\,\mathrm{sign}\left(\mathrm{q2d}\right)+0.01462\,{\mathrm{q3d}}^2\,\mathrm{sign}\left(\mathrm{q3d}\right)+0.8947\,\mathrm{q1d}\,\mathrm{q2d}\,\sin\left(q_{1}\right)-1.133\,\mathrm{q1d}\,\mathrm{q2d}\,\sin\left(q_{2}\right)+0.4313\,\mathrm{q1d}\,\mathrm{q3d}\,\sin\left(q_{1}\right)+0.4025\,\mathrm{q1d}\,\mathrm{q2d}\,\sin\left(q_{3}\right)-2.295\,\mathrm{q1d}\,\mathrm{q3d}\,\sin\left(q_{2}\right)-0.2033\,\mathrm{q2d}\,\mathrm{q3d}\,\sin\left(q_{1}\right)-1.008\,\mathrm{q1d}\,\mathrm{q3d}\,\sin\left(q_{3}\right)-2.73\,\mathrm{q2d}\,\mathrm{q3d}\,\sin\left(q_{2}\right)-2.306\,\mathrm{q2d}\,\mathrm{q3d}\,\sin\left(q_{3}\right)\\ 0.4156\,{\mathrm{q2d}}^2\,\sin\left(q_{1}\right)-1.066\,{\mathrm{q1d}}^2\,\sin\left(q_{2}\right)-0.4584\,{\mathrm{q1d}}^2\,\sin\left(q_{1}\right)-0.2534\,{\mathrm{q1d}}^2\,\sin\left(q_{3}\right)+3.93\,{\mathrm{q2d}}^2\,\sin\left(q_{2}\right)-0.1174\,{\mathrm{q3d}}^2\,\sin\left(q_{1}\right)-1.473\,{\mathrm{q2d}}^2\,\sin\left(q_{3}\right)+1.023\,{\mathrm{q3d}}^2\,\sin\left(q_{2}\right)+0.2968\,{\mathrm{q3d}}^2\,\sin\left(q_{3}\right)-0.1539\,{\mathrm{q1d}}^2\,\mathrm{sign}\left(\mathrm{q1d}\right)-0.4011\,{\mathrm{q2d}}^2\,\mathrm{sign}\left(\mathrm{q2d}\right)+0.08319\,{\mathrm{q3d}}^2\,\mathrm{sign}\left(\mathrm{q3d}\right)-0.327\,\mathrm{q1d}\,\mathrm{q2d}\,\sin\left(q_{1}\right)-1.412\,\mathrm{q1d}\,\mathrm{q2d}\,\sin\left(q_{2}\right)-0.01043\,\mathrm{q1d}\,\mathrm{q3d}\,\sin\left(q_{1}\right)-0.2724\,\mathrm{q1d}\,\mathrm{q2d}\,\sin\left(q_{3}\right)+0.336\,\mathrm{q1d}\,\mathrm{q3d}\,\sin\left(q_{2}\right)+1.195\,\mathrm{q2d}\,\mathrm{q3d}\,\sin\left(q_{1}\right)-0.2048\,\mathrm{q1d}\,\mathrm{q3d}\,\sin\left(q_{3}\right)-0.5121\,\mathrm{q2d}\,\mathrm{q3d}\,\sin\left(q_{2}\right)+0.6851\,\mathrm{q2d}\,\mathrm{q3d}\,\sin\left(q_{3}\right)\\ 0.7548\,{\mathrm{q1d}}^2\,\sin\left(q_{1}\right)-0.8502\,{\mathrm{q1d}}^2\,\sin\left(q_{2}\right)+0.2569\,{\mathrm{q2d}}^2\,\sin\left(q_{1}\right)-0.5142\,{\mathrm{q1d}}^2\,\sin\left(q_{3}\right)-1.84\,{\mathrm{q2d}}^2\,\sin\left(q_{2}\right)-0.2368\,{\mathrm{q3d}}^2\,\sin\left(q_{1}\right)-1.567\,{\mathrm{q2d}}^2\,\sin\left(q_{3}\right)+1.029\,{\mathrm{q3d}}^2\,\sin\left(q_{2}\right)-0.5209\,{\mathrm{q3d}}^2\,\sin\left(q_{3}\right)-0.06068\,{\mathrm{q1d}}^2\,\mathrm{sign}\left(\mathrm{q1d}\right)-0.602\,{\mathrm{q2d}}^2\,\mathrm{sign}\left(\mathrm{q2d}\right)+0.1551\,{\mathrm{q3d}}^2\,\mathrm{sign}\left(\mathrm{q3d}\right)+1.119\,\mathrm{q1d}\,\mathrm{q2d}\,\sin\left(q_{1}\right)+0.7213\,\mathrm{q1d}\,\mathrm{q2d}\,\sin\left(q_{2}\right)-1.194\,\mathrm{q1d}\,\mathrm{q3d}\,\sin\left(q_{1}\right)-0.07641\,\mathrm{q1d}\,\mathrm{q2d}\,\sin\left(q_{3}\right)+1.309\,\mathrm{q1d}\,\mathrm{q3d}\,\sin\left(q_{2}\right)-0.7603\,\mathrm{q2d}\,\mathrm{q3d}\,\sin\left(q_{1}\right)+0.5784\,\mathrm{q1d}\,\mathrm{q3d}\,\sin\left(q_{3}\right)+3.092\,\mathrm{q2d}\,\mathrm{q3d}\,\sin\left(q_{2}\right)+0.8252\,\mathrm{q2d}\,\mathrm{q3d}\,\sin\left(q_{3}\right) \end{array}\right)
#
# \end{aligned}

# %% [markdown]
# \begin{aligned}
# G =
#
#     \left(\begin{array}{c} -2.638\,{\cos\left(q_{1}\right)}^2+5.316\,\cos\left(q_{1}\right)\,\cos\left(q_{2}\right)-2.192\,\cos\left(q_{1}\right)\,\cos\left(q_{3}\right)-8.624\,{\cos\left(q_{2}\right)}^2+1.817\,\cos\left(q_{2}\right)\,\cos\left(q_{3}\right)+1.025\,{\cos\left(q_{3}\right)}^2-5.316\,\sin\left(q_{1}\right)\,\sin\left(q_{2}\right)+2.192\,\sin\left(q_{1}\right)\,\sin\left(q_{3}\right)-1.817\,\sin\left(q_{2}\right)\,\sin\left(q_{3}\right)+5.119\\ -3.623\,{\cos\left(q_{1}\right)}^2+1.776\,\cos\left(q_{1}\right)\,\cos\left(q_{2}\right)+0.9568\,\cos\left(q_{1}\right)\,\cos\left(q_{3}\right)-0.07163\,{\cos\left(q_{2}\right)}^2-7.632\,\cos\left(q_{2}\right)\,\cos\left(q_{3}\right)-3.667\,{\cos\left(q_{3}\right)}^2-1.776\,\sin\left(q_{1}\right)\,\sin\left(q_{2}\right)-0.9568\,\sin\left(q_{1}\right)\,\sin\left(q_{3}\right)+7.632\,\sin\left(q_{2}\right)\,\sin\left(q_{3}\right)+3.681\\ 0.05964\,{\cos\left(q_{1}\right)}^2+1.048\,\cos\left(q_{1}\right)\,\cos\left(q_{2}\right)-0.3789\,\cos\left(q_{1}\right)\,\cos\left(q_{3}\right)+0.4395\,{\cos\left(q_{2}\right)}^2-11.68\,\cos\left(q_{2}\right)\,\cos\left(q_{3}\right)-1.589\,{\cos\left(q_{3}\right)}^2-1.048\,\sin\left(q_{1}\right)\,\sin\left(q_{2}\right)+0.3789\,\sin\left(q_{1}\right)\,\sin\left(q_{3}\right)+11.68\,\sin\left(q_{2}\right)\,\sin\left(q_{3}\right)+0.5448 \end{array}\right)
# \end{aligned}
